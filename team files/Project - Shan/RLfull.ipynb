# %%
import pandas as pd
import networkx as nx

# %%
student_data = pd.read_csv("synthetic_student_data.csv")

# %%
student_data.head()
# Out:
#   StudentID  Academic_Performance  isolated  WomenDifferent  language  COVID  \
# 0     S0001                    61         3               4         0      4
# 1     S0002                    53         6               5         1      4
# 2     S0003                    62         3               6         0      2
# 3     S0004                    96         3               2         1      2
# 4     S0005                    68         5               6         0      7
#
#    criticises  MenBetterSTEM  pwi_wellbeing  Intelligence1  ...  k6_4  k6_5  \
# 0           1              2              8              6  ...     1     1
# 1           4              2              1              5  ...     5     1
# 2           1              3              0              3  ...     1     3
# 3           2              2              0              1  ...     3     4
# 4           2              7              3              4  ...     2     2
#
#    k6_6  Manbox5_overall  Masculinity_contrained  GrowthMindset  k6_overall  \
# 0     1              2.2                    3.75            2.5           7
# 1     1              5.4                    3.75            5.0          17
# 2     1              4.0                    4.00            5.5          15
# 3     2              2.0                    3.25            5.0          19
# 4     5              4.0                    4.75            3.0          18
#
#    School_support_engage                                          Friends  \
# 0                   4.50                S0260, S0282, S0993, S0955, S0724
# 1                   4.00                              S0480, S0819, S0325
# 2                   4.75                       S0356, S0942, S0978, S0556
# 3                   2.75  S0725, S0124, S0879, S0177, S0738, S0648, S0105
# 4                   4.75                       S0627, S0454, S0098, S0028
#
#    Friends_Count
# 0              5
# 1              3
# 2              4
# 3              7
# 4              4
#
# [5 rows x 35 columns]

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   StudentID               1000 non-null   object
#  1   Academic_Performance    1000 non-null   int64
#  2   isolated                1000 non-null   int64
#  3   WomenDifferent          1000 non-null   int64
#  4   language                1000 non-null   int64
#  5   COVID                   1000 non-null   int64
#  6   criticises              1000 non-null   int64
#  7   MenBetterSTEM           1000 non-null   int64
#  8   pwi_wellbeing           1000 non-null   int64
#  9   Intelligence1           1000 non-null   int64
#  10  Intelligence2           1000 non-null   int64
#  11  Soft                    1000 non-null   int64
#  12  opinion                 1000 non-null   int64
#  13  Nerds                   1000 non-null   int64
#  14  comfortable             1000 non-null   int64
#  15  future                  1000 non-null   int64
#  16  bullying                1000 non-null   int64
#  17  Manbox5_1               1000 non-null   int64
#  18  Manbox5_2               1000 non-null   int64
#  19  Manbox5_3               1000 non-null   int64
#  20  Manbox5_4               1000 non-null   int64
#  21  Manbox5_5               1000 non-null   int64
#  22  k6_1                    1000 non-null   int64
#  23  k6_2                    1000 non-null   int64
#  24  k6_3                    1000 non-null   int64
#  25  k6_4                    1000 non-null   int64
#  26  k6_5                    1000 non-null   int64
#  27  k6_6                    1000 non-null   int64
#  28  Manbox5_overall         1000 non-null   float64
#  29  Masculinity_contrained  1000 non-null   float64
#  30  GrowthMindset           1000 non-null   float64
#  31  k6_overall              1000 non-null   int64
#  32  School_support_engage   1000 non-null   float64
#  33  Friends                 876 non-null    object
#  34  Friends_Count           1000 non-null   int64
# dtypes: float64(4), int64(29), object(2)
# memory usage: 273.6+ KB

# %%
# Step 1: Check for missing values
student_data.isnull().sum()
# Out:
# StudentID                   0
# Academic_Performance        0
# isolated                    0
# WomenDifferent              0
# language                    0
# COVID                       0
# criticises                  0
# MenBetterSTEM               0
# pwi_wellbeing               0
# Intelligence1               0
# Intelligence2               0
# Soft                        0
# opinion                     0
# Nerds                       0
# comfortable                 0
# future                      0
# bullying                    0
# Manbox5_1                   0
# Manbox5_2                   0
# Manbox5_3                   0
# Manbox5_4                   0
# Manbox5_5                   0
# k6_1                        0
# k6_2                        0
# k6_3                        0
# k6_4                        0
# k6_5                        0
# k6_6                        0
# Manbox5_overall             0
# Masculinity_contrained      0
# GrowthMindset               0
# k6_overall                  0
# School_support_engage       0
# Friends                   124
# Friends_Count               0
# dtype: int64

# %%
# Step 2: Clean the 'Friends' column safely
student_data['Friends'] = student_data['Friends'].fillna('')  # Fill NaN with empty string

# Convert to list only if it's a string
student_data['Friends'] = student_data['Friends'].apply(
    lambda x: [] if x == '' else (x if isinstance(x, list) else x.split(','))
)

# %%
# Step 3: Check for dulicate values
student_data_no_friends = student_data.drop(columns=['Friends'])
duplicate_rows = student_data[student_data_no_friends.duplicated()]
print(f"Duplicate rows found (excluding 'Friends'): {len(duplicate_rows)}")

duplicate_ids = student_data[student_data.duplicated(subset='StudentID')]
print(f"Duplicate StudentIDs found: {len(duplicate_ids)}")
# Out:
# Duplicate rows found (excluding 'Friends'): 0
# Duplicate StudentIDs found: 0

# %%
# Step 4: Check basic statistical summary to find outliers or weird values
student_data.describe()
# Out:
#        Academic_Performance     isolated  WomenDifferent     language  \
# count           1000.000000  1000.000000     1000.000000  1000.000000
# mean              70.360000     3.965000        3.973000     0.222000
# std               14.478053     2.037136        1.924571     0.415799
# min               23.000000     1.000000        1.000000     0.000000
# 25%               60.000000     2.000000        2.000000     0.000000
# 50%               70.000000     4.000000        4.000000     0.000000
# 75%               80.000000     6.000000        6.000000     0.000000
# max              100.000000     7.000000        7.000000     1.000000
#
#              COVID  criticises  MenBetterSTEM  pwi_wellbeing  Intelligence1  \
# count  1000.000000  1000.00000    1000.000000    1000.000000     1000.00000
# mean      3.992000     3.96500       4.073000       4.865000        3.95900
# std       1.979863     1.99744       1.987365       3.167777        2.00033
# min       1.000000     1.00000       1.000000       0.000000        1.00000
# 25%       2.000000     2.00000       2.000000       2.000000        2.00000
# 50%       4.000000     4.00000       4.000000       5.000000        4.00000
# 75%       6.000000     6.00000       6.000000       7.000000        6.00000
# max       7.000000     7.00000       7.000000      10.000000        7.00000
#
#        Intelligence2  ...         k6_3         k6_4         k6_5         k6_6  \
# count    1000.000000  ...  1000.000000  1000.000000  1000.000000  1000.000000
# mean        3.952000  ...     3.002000     2.855000     3.012000     3.023000
# std         1.983338  ...     1.376914     1.401406     1.376136     1.436849
# min         1.000000  ...     1.000000     1.000000     1.000000     1.000000
# 25%         2.000000  ...     2.000000     2.000000     2.000000     2.000000
# 50%         4.000000  ...     3.000000     3.000000     3.000000     3.000000
# 75%         6.000000  ...     4.000000     4.000000     4.000000     4.000000
# max         7.000000  ...     5.000000     5.000000     5.000000     5.000000
#
#        Manbox5_overall  Masculinity_contrained  GrowthMindset   k6_overall  \
# count      1000.000000              1000.00000    1000.000000  1000.000000
# mean          4.004600                 4.00950       4.044500    17.830000
# std           0.900505                 1.00208       1.436431     3.482704
# min           1.400000                 1.25000       1.000000     7.000000
# 25%           3.400000                 3.25000       3.000000    16.000000
# 50%           4.000000                 4.00000       4.000000    18.000000
# 75%           4.600000                 4.75000       5.000000    20.000000
# max           7.000000                 6.75000       7.000000    28.000000
#
#        School_support_engage  Friends_Count
# count            1000.000000    1000.000000
# mean                3.986500       3.504000
# std                 1.019918       2.308097
# min                 1.000000       0.000000
# 25%                 3.250000       1.000000
# 50%                 4.000000       3.000000
# 75%                 4.750000       6.000000
# max                 7.000000       7.000000
#
# [8 rows x 33 columns]

# %%
# Step 5: Create the required fields
processed_data = student_data.copy()

# Create the fields
processed_data['Wellbeing_Score'] = processed_data['pwi_wellbeing']
processed_data['Friendliness_Score'] = processed_data['School_support_engage']
processed_data['Bullying_Score'] = processed_data['criticises']
processed_data['Composite_Score'] = (
    0.5 * processed_data['Academic_Performance'] +
    0.3 * processed_data['Wellbeing_Score'] +
    0.2 * processed_data['Friendliness_Score']
)
processed_data['Is_Bully'] = processed_data['Bullying_Score'] >= 5

# Show the first few rows to confirm
processed_data[['StudentID', 'Academic_Performance', 'Wellbeing_Score', 
                'Friendliness_Score', 'Bullying_Score', 'Composite_Score', 'Is_Bully']].head()
# Out:
#   StudentID  Academic_Performance  Wellbeing_Score  Friendliness_Score  \
# 0     S0001                    61                8                4.50
# 1     S0002                    53                1                4.00
# 2     S0003                    62                0                4.75
# 3     S0004                    96                0                2.75
# 4     S0005                    68                3                4.75
#
#    Bullying_Score  Composite_Score  Is_Bully
# 0               1            33.80     False
# 1               4            27.60     False
# 2               1            31.95     False
# 3               2            48.55     False
# 4               2            35.85     False

# %%
# Step 6: Create Social Network Graph
# Load the dataset
student_data = pd.read_csv("synthetic_student_data.csv")

# Initialize the graph
G = nx.Graph()

# Add nodes
G.add_nodes_from(student_data["StudentID"])

# Add edges from the 'Friends' column
for _, row in student_data.iterrows():
    student = row["StudentID"]
    if pd.notna(row["Friends"]):
        friends = [f.strip() for f in row["Friends"].split(",")]
        for friend in friends:
            G.add_edge(student, friend)

# Print basic stats
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())
print("Is the graph connected?", nx.is_connected(G))
# Out:
# Number of nodes: 1000
# Number of edges: 3499
# Is the graph connected? False

# %%
components = list(nx.connected_components(G))
print(f"Number of connected components: {len(components)}")
# Out:
# Number of connected components: 6

# %%
# Degree Centrality
degree_centrality = nx.degree_centrality(G)
student_data["degree_centrality"] = student_data["StudentID"].map(degree_centrality)

# Clustering Coefficient
clustering = nx.clustering(G)
student_data["clustering"] = student_data["StudentID"].map(clustering)

# Component Label (which cluster the student belongs to)
component_map = {}
for i, comp in enumerate(components):
    for node in comp:
        component_map[node] = i
student_data["component_id"] = student_data["StudentID"].map(component_map)

# Preview the updated table
student_data[["StudentID", "degree_centrality", "clustering", "component_id"]].head(10)
# Out:
#   StudentID  degree_centrality  clustering  component_id
# 0     S0001           0.007007    0.000000             0
# 1     S0002           0.006006    0.000000             0
# 2     S0003           0.007007    0.000000             0
# 3     S0004           0.011011    0.000000             0
# 4     S0005           0.005005    0.000000             0
# 5     S0006           0.009009    0.000000             0
# 6     S0007           0.004004    0.166667             0
# 7     S0008           0.006006    0.000000             0
# 8     S0009           0.007007    0.047619             0
# 9     S0010           0.008008    0.035714             0

# %%
import numpy as np
import random
import pandas as pd

class StudentAssignmentEnv:
    def __init__(self, students_df, n_classes=4):
        self.students = students_df.copy()
        self.classrooms = {f"Class_{i}": [] for i in range(n_classes)}
        self.n_classes = n_classes
        self.reset()

    def reset(self):
        self.classrooms = {f"Class_{i}": [] for i in range(self.n_classes)}
        # Sort students by Composite Score descending
        self.unassigned_students = self.students.sort_values(by='Composite_Score', ascending=False).index.tolist()
        return self._get_state()

    def _get_state(self):
        state = {
            'classroom_sizes': [len(cls) for cls in self.classrooms.values()],
            'unassigned': self.unassigned_students.copy()
        }
        return state

    def step(self, action_classroom):
        if not self.unassigned_students:
            return self._get_state(), 0, True

        student_idx = self.unassigned_students.pop(0)
        student = self.students.loc[student_idx]
        self.classrooms[action_classroom].append(student_idx)

        done = len(self.unassigned_students) == 0

        if done:
            reward, academic_std, wellbeing_std, bullying_penalty = self._calculate_reward()
        else:
            reward, academic_std, wellbeing_std, bullying_penalty = 0, 0, 0, 0

        return self._get_state(), reward, done, academic_std, wellbeing_std, bullying_penalty

    def _calculate_reward(self):
        academic_scores = []
        wellbeing_scores = []
        bullying_risks = []
        total_students = sum(len(cls) for cls in self.classrooms.values())

        for cls_indices in self.classrooms.values():
            if not cls_indices:
                continue
            cls_students = self.students.loc[cls_indices]
            sampled_students = cls_students.sample(n=min(20, len(cls_students)))
            academic_scores.append(sampled_students['Academic_Performance'].mean())
            wellbeing_scores.append(sampled_students['Wellbeing_Score'].mean())
            bullying_risks.append(sampled_students['Is_Bully'].sum())

        academic_std = np.std(academic_scores)
        wellbeing_std = np.std(wellbeing_scores)
        bullying_penalty = sum(bullying_risks) / max(total_students, 1)

        # Clamp values to prevent explosion
        academic_std = min(academic_std, 10)
        wellbeing_std = min(wellbeing_std, 5)

        reward = -((academic_std / 100) + (wellbeing_std / 10) + bullying_penalty)
        return reward, academic_std, wellbeing_std, bullying_penalty

# %%
# Dummy student dataset for testing
n_students = 100
students_df = pd.DataFrame({
    'Composite_Score': np.random.uniform(0, 100, n_students),
    'Academic_Performance': np.random.uniform(60, 100, n_students),
    'Wellbeing_Score': np.random.uniform(5, 10, n_students),
    'Is_Bully': np.random.choice([0, 1], size=n_students, p=[0.9, 0.1])
})

# Instantiate the environment
env = StudentAssignmentEnv(students_df, n_classes=4)

# Reset environment
state = env.reset()
done = False

# Random assignment of students to classrooms
while not done:
    random_class = f"Class_{random.randint(0, env.n_classes - 1)}"
    state, reward, done, academic_std, wellbeing_std, bullying_penalty = env.step(random_class)

# Print the final results
print("Test Environment Completed")
print(f"Final Reward: {reward:.4f}")
print(f"Academic Std Deviation: {academic_std:.2f}")
print(f"Wellbeing Std Deviation: {wellbeing_std:.2f}")
print(f"Bullying Penalty: {bullying_penalty:.4f}")
# Out:
# Test Environment Completed
# Final Reward: -0.0901
# Academic Std Deviation: 0.68
# Wellbeing Std Deviation: 0.03
# Bullying Penalty: 0.0800

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.11/site-packages (2.7.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# ----------------------------------
# 1. Import Libraries
# ----------------------------------
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
import matplotlib.pyplot as plt

# ----------------------------------
# 2. Define DQN Model
# ----------------------------------
class DQNModel(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# ----------------------------------
# 3. Define DQN Agent
# ----------------------------------
class DQNAgent:
    def __init__(self, input_dim, output_dim, lr=0.001, gamma=0.9, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01):
        self.model = DQNModel(input_dim, output_dim)
        self.target_model = DQNModel(input_dim, output_dim)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.criterion = nn.MSELoss()
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.output_dim = output_dim

    def choose_action(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, self.output_dim - 1)
        else:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            q_values = self.model(state_tensor)
            return torch.argmax(q_values).item()

    def train_step(self, state, action, reward, next_state, done):
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
        reward_tensor = torch.FloatTensor([reward])
        action_tensor = torch.LongTensor([action])

        q_value = self.model(state_tensor).gather(1, action_tensor.unsqueeze(1)).squeeze(1)
        next_q_value = self.target_model(next_state_tensor).max(1)[0]
        expected_q_value = reward_tensor + (1 - int(done)) * self.gamma * next_q_value

        loss = self.criterion(q_value, expected_q_value.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def decay_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# ----------------------------------
# 4. Train the DQN Agent
# ----------------------------------
n_episodes = 150  # Longer training

agent = DQNAgent(input_dim=4, output_dim=4, epsilon_min=0.01)  # 🔥 Lower epsilon_min

academic_stds = []
wellbeing_stds = []
bullying_penalties = []
normalized_rewards = []

for episode in range(n_episodes):
    state_data = env.reset()
    total_custom_reward = 0
    done = False
    steps = 0

    academic_std_episode = 0
    wellbeing_std_episode = 0
    bullying_penalty_episode = 0

    while not done:
        classroom_sizes = np.array(state_data['classroom_sizes']) / 10000  # Normalize
        action = agent.choose_action(classroom_sizes)

        next_state_data, _, done, academic_std, wellbeing_std, bullying_penalty = env.step(f"Class_{action}")
        next_classroom_sizes = np.array(next_state_data['classroom_sizes']) / 10000

        # Updated stronger reward calculation
        custom_reward = (
            0.7 * (1 - min(academic_std, 5) / 10) +   # Stronger academic penalty + cap academic std
            0.2 * (1 - wellbeing_std / 10) +
            0.1 * (1 - bullying_penalty * 100)
        )

        agent.train_step(classroom_sizes, action, custom_reward, next_classroom_sizes, done)

        total_custom_reward += custom_reward
        state_data = next_state_data
        steps += 1

        academic_std_episode = academic_std
        wellbeing_std_episode = wellbeing_std
        bullying_penalty_episode = bullying_penalty

    normalized_reward = (total_custom_reward / steps) * 1000  # Smooth reward scale
    normalized_rewards.append(normalized_reward)
    academic_stds.append(academic_std_episode)
    wellbeing_stds.append(wellbeing_std_episode)
    bullying_penalties.append(bullying_penalty_episode)

    agent.decay_epsilon()

    if (episode + 1) % 10 == 0:
        agent.update_target()
        print(f"Episode {episode + 1}:")
        print(f"  Total Normalized Reward: {normalized_reward:.2f}")
        print(f"  Academic Std Deviation: {academic_std_episode:.2f}")
        print(f"  Wellbeing Std Deviation: {wellbeing_std_episode:.2f}")
        print(f"  Bullying Penalty: {bullying_penalty_episode:.4f}")
        print("-" * 40)

# ----------------------------------
# 5. Plotting Results
# ----------------------------------

episodes = np.arange(1, n_episodes + 1)

plt.figure(figsize=(8, 5))
plt.plot(episodes, academic_stds, marker='o')
plt.title('Academic Standard Deviation over Episodes')
plt.xlabel('Episode')
plt.ylabel('Academic Std Deviation')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, wellbeing_stds, marker='o', color='orange')
plt.title('Wellbeing Standard Deviation over Episodes')
plt.xlabel('Episode')
plt.ylabel('Wellbeing Std Deviation')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, bullying_penalties, marker='o', color='green')
plt.title('Bullying Penalty over Episodes')
plt.xlabel('Episode')
plt.ylabel('Bullying Penalty')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, normalized_rewards, marker='o', color='purple')
plt.title('Normalized Reward over Episodes')
plt.xlabel('Episode')
plt.ylabel('Normalized Reward')
plt.grid(True)
plt.show()
# Out:
# Episode 10:
#   Total Normalized Reward: 992.29
#   Academic Std Deviation: 0.97
#   Wellbeing Std Deviation: 0.15
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 20:
#   Total Normalized Reward: 991.56
#   Academic Std Deviation: 3.45
#   Wellbeing Std Deviation: 0.12
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 30:
#   Total Normalized Reward: 992.05
#   Academic Std Deviation: 1.35
#   Wellbeing Std Deviation: 0.05
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 40:
#   Total Normalized Reward: 991.20
#   Academic Std Deviation: 2.47
#   Wellbeing Std Deviation: 0.38
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 50:
#   Total Normalized Reward: 993.34
#   Academic Std Deviation: 0.93
#   Wellbeing Std Deviation: 0.05
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 60:
#   Total Normalized Reward: 990.43
#   Academic Std Deviation: 3.56
#   Wellbeing Std Deviation: 0.37
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 70:
#   Total Normalized Reward: 991.17
#   Academic Std Deviation: 2.55
#   Wellbeing Std Deviation: 0.23
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 80:
#   Total Normalized Reward: 993.26
#   Academic Std Deviation: 2.41
#   Wellbeing Std Deviation: 0.27
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 90:
#   Total Normalized Reward: 992.56
#   Academic Std Deviation: 2.01
#   Wellbeing Std Deviation: 0.13
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 100:
#   Total Normalized Reward: 991.40
#   Academic Std Deviation: 2.19
#   Wellbeing Std Deviation: 0.33
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 110:
#   Total Normalized Reward: 988.49
#   Academic Std Deviation: 4.89
#   Wellbeing Std Deviation: 0.45
#   Bullying Penalty: 0.0800
# ----------------------------------------
# Episode 120:
#   Total Normalized Reward: 995.18
#   Academic Std Deviation: 2.56
#   Wellbeing Std Deviation: 0.13
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 130:
#   Total Normalized Reward: 992.39
#   Academic Std Deviation: 2.21
#   Wellbeing Std Deviation: 0.32
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 140:
#   Total Normalized Reward: 994.29
#   Academic Std Deviation: 0.93
#   Wellbeing Std Deviation: 0.32
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 150:
#   Total Normalized Reward: 993.04
#   Academic Std Deviation: 1.23
#   Wellbeing Std Deviation: 0.51
#   Bullying Penalty: 0.0600
# ----------------------------------------

# %%
# 1. Import Libraries
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
import matplotlib.pyplot as plt

# 2. Define DQN Model
class DQNModel(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# 3. Define DQN Agent
class DQNAgent:
    def __init__(self, input_dim, output_dim, lr=0.0005, gamma=0.9, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01):
        self.model = DQNModel(input_dim, output_dim)
        self.target_model = DQNModel(input_dim, output_dim)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.criterion = nn.MSELoss()
        self.gamma = gamma
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.output_dim = output_dim

    def choose_action(self, state):
        if random.random() < self.epsilon:
            return random.randint(0, self.output_dim - 1)
        else:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            q_values = self.model(state_tensor)
            return torch.argmax(q_values).item()

    def train_step(self, state, action, reward, next_state, done):
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
        reward_tensor = torch.FloatTensor([reward])
        action_tensor = torch.LongTensor([action])

        q_value = self.model(state_tensor).gather(1, action_tensor.unsqueeze(1)).squeeze(1)
        next_q_value = self.target_model(next_state_tensor).max(1)[0]
        expected_q_value = reward_tensor + (1 - int(done)) * self.gamma * next_q_value

        loss = self.criterion(q_value, expected_q_value.detach())

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def decay_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# 4. Continue Training from Episode 150
# Set up for continued training from episode 150
n_episodes = 500  # Total number of episodes to run

agent = DQNAgent(input_dim=4, output_dim=4, epsilon_min=0.01)  # Reduced learning rate for fine-tuning
academic_stds = []
wellbeing_stds = []
bullying_penalties = []
normalized_rewards = []

# Load previous model state (after 150 episodes)
# agent.model.load_state_dict(torch.load('model_after_150_episodes.pth')) 

for episode in range(151, n_episodes + 1):  # Continue training from episode 151
    state_data = env.reset()
    total_custom_reward = 0
    done = False
    steps = 0

    academic_std_episode = 0
    wellbeing_std_episode = 0
    bullying_penalty_episode = 0

    while not done:
        classroom_sizes = np.array(state_data['classroom_sizes']) / 10000  # Normalize
        action = agent.choose_action(classroom_sizes)

        next_state_data, _, done, academic_std, wellbeing_std, bullying_penalty = env.step(f"Class_{action}")
        next_classroom_sizes = np.array(next_state_data['classroom_sizes']) / 10000

        # Updated stronger reward calculation
        custom_reward = (
            0.7 * (1 - min(academic_std, 5) / 10) +   # Stronger academic penalty + cap academic std
            0.2 * (1 - wellbeing_std / 10) +
            0.1 * (1 - bullying_penalty * 100)
        )

        agent.train_step(classroom_sizes, action, custom_reward, next_classroom_sizes, done)

        total_custom_reward += custom_reward
        state_data = next_state_data
        steps += 1

        academic_std_episode = academic_std
        wellbeing_std_episode = wellbeing_std
        bullying_penalty_episode = bullying_penalty

    normalized_reward = (total_custom_reward / steps) * 1000  # Smooth reward scale
    normalized_rewards.append(normalized_reward)
    academic_stds.append(academic_std_episode)
    wellbeing_stds.append(wellbeing_std_episode)
    bullying_penalties.append(bullying_penalty_episode)

    agent.decay_epsilon()

    if (episode + 1) % 10 == 0:
        agent.update_target()
        print(f"Episode {episode}:")
        print(f"  Total Normalized Reward: {normalized_reward:.2f}")
        print(f"  Academic Std Deviation: {academic_std_episode:.2f}")
        print(f"  Wellbeing Std Deviation: {wellbeing_std_episode:.2f}")
        print(f"  Bullying Penalty: {bullying_penalty_episode:.4f}")
        print("-" * 40)

    # Save the model after training every 50 episodes to avoid losing progress
    if (episode + 1) % 50 == 0 or episode == 499:
        torch.save(agent.model.state_dict(), f"model_after_{episode + 1}_episodes.pth")

# 5. Plotting Results
episodes = np.arange(151, n_episodes + 1)

plt.figure(figsize=(8, 5))
plt.plot(episodes, academic_stds, marker='o')
plt.title('Academic Standard Deviation over Episodes')
plt.xlabel('Episode')
plt.ylabel('Academic Std Deviation')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, wellbeing_stds, marker='o', color='orange')
plt.title('Wellbeing Standard Deviation over Episodes')
plt.xlabel('Episode')
plt.ylabel('Wellbeing Std Deviation')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, bullying_penalties, marker='o', color='green')
plt.title('Bullying Penalty over Episodes')
plt.xlabel('Episode')
plt.ylabel('Bullying Penalty')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, normalized_rewards, marker='o', color='purple')
plt.title('Normalized Reward over Episodes')
plt.xlabel('Episode')
plt.ylabel('Normalized Reward')
plt.grid(True)
plt.show()
# Out:
# Episode 159:
#   Total Normalized Reward: 989.32
#   Academic Std Deviation: 3.77
#   Wellbeing Std Deviation: 0.21
#   Bullying Penalty: 0.0800
# ----------------------------------------
# Episode 169:
#   Total Normalized Reward: 993.25
#   Academic Std Deviation: 2.43
#   Wellbeing Std Deviation: 0.28
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 179:
#   Total Normalized Reward: 993.03
#   Academic Std Deviation: 1.26
#   Wellbeing Std Deviation: 0.43
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 189:
#   Total Normalized Reward: 993.19
#   Academic Std Deviation: 2.46
#   Wellbeing Std Deviation: 0.44
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 199:
#   Total Normalized Reward: 991.93
#   Academic Std Deviation: 1.49
#   Wellbeing Std Deviation: 0.14
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 209:
#   Total Normalized Reward: 993.94
#   Academic Std Deviation: 2.88
#   Wellbeing Std Deviation: 0.26
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 219:
#   Total Normalized Reward: 992.42
#   Academic Std Deviation: 3.64
#   Wellbeing Std Deviation: 0.15
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 229:
#   Total Normalized Reward: 993.09
#   Academic Std Deviation: 2.60
#   Wellbeing Std Deviation: 0.42
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 239:
#   Total Normalized Reward: 992.44
#   Academic Std Deviation: 2.07
#   Wellbeing Std Deviation: 0.57
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 249:
#   Total Normalized Reward: 991.46
#   Academic Std Deviation: 2.14
#   Wellbeing Std Deviation: 0.21
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 259:
#   Total Normalized Reward: 994.75
#   Academic Std Deviation: 3.10
#   Wellbeing Std Deviation: 0.42
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 269:
#   Total Normalized Reward: 990.28
#   Academic Std Deviation: 3.73
#   Wellbeing Std Deviation: 0.54
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 279:
#   Total Normalized Reward: 994.75
#   Academic Std Deviation: 3.14
#   Wellbeing Std Deviation: 0.24
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 289:
#   Total Normalized Reward: 992.84
#   Academic Std Deviation: 1.59
#   Wellbeing Std Deviation: 0.22
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 299:
#   Total Normalized Reward: 992.63
#   Academic Std Deviation: 1.90
#   Wellbeing Std Deviation: 0.18
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 309:
#   Total Normalized Reward: 990.86
#   Academic Std Deviation: 4.42
#   Wellbeing Std Deviation: 0.21
#   Bullying Penalty: 0.0600
# ----------------------------------------
# Episode 319:
#   Total Normalized Reward: 993.24
#   Academic Std Deviation: 2.41
#   Wellbeing Std Deviation: 0.39
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 329:
#   Total Normalized Reward: 994.15
#   Academic Std Deviation: 2.62
#   Wellbeing Std Deviation: 0.08
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 339:
#   Total Normalized Reward: 991.39
#   Academic Std Deviation: 5.04
#   Wellbeing Std Deviation: 0.54
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 349:
#   Total Normalized Reward: 993.96
#   Academic Std Deviation: 2.86
#   Wellbeing Std Deviation: 0.23
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 359:
#   Total Normalized Reward: 996.35
#   Academic Std Deviation: 0.80
#   Wellbeing Std Deviation: 0.45
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 369:
#   Total Normalized Reward: 994.76
#   Academic Std Deviation: 4.51
#   Wellbeing Std Deviation: 0.42
#   Bullying Penalty: 0.0200
# ----------------------------------------
# Episode 379:
#   Total Normalized Reward: 992.65
#   Academic Std Deviation: 3.21
#   Wellbeing Std Deviation: 0.50
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 389:
#   Total Normalized Reward: 991.34
#   Academic Std Deviation: 5.99
#   Wellbeing Std Deviation: 0.79
#   Bullying Penalty: 0.0500
# ----------------------------------------
# Episode 399:
#   Total Normalized Reward: 994.34
#   Academic Std Deviation: 5.45
#   Wellbeing Std Deviation: 0.79
#   Bullying Penalty: 0.0200
# ----------------------------------------
# Episode 409:
#   Total Normalized Reward: 995.09
#   Academic Std Deviation: 3.96
#   Wellbeing Std Deviation: 0.67
#   Bullying Penalty: 0.0200
# ----------------------------------------
# Episode 419:
#   Total Normalized Reward: 993.07
#   Academic Std Deviation: 4.11
#   Wellbeing Std Deviation: 0.25
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 429:
#   Total Normalized Reward: 992.65
#   Academic Std Deviation: 4.68
#   Wellbeing Std Deviation: 0.37
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 439:
#   Total Normalized Reward: 995.36
#   Academic Std Deviation: 6.58
#   Wellbeing Std Deviation: 0.68
#   Bullying Penalty: 0.0100
# ----------------------------------------
# Episode 449:
#   Total Normalized Reward: 989.44
#   Academic Std Deviation: 5.33
#   Wellbeing Std Deviation: 0.28
#   Bullying Penalty: 0.0700
# ----------------------------------------
# Episode 459:
#   Total Normalized Reward: 995.25
#   Academic Std Deviation: 3.82
#   Wellbeing Std Deviation: 0.39
#   Bullying Penalty: 0.0200
# ----------------------------------------
# Episode 469:
#   Total Normalized Reward: 995.19
#   Academic Std Deviation: 3.97
#   Wellbeing Std Deviation: 0.16
#   Bullying Penalty: 0.0200
# ----------------------------------------
# Episode 479:
#   Total Normalized Reward: 994.08
#   Academic Std Deviation: 3.97
#   Wellbeing Std Deviation: 0.71
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 489:
#   Total Normalized Reward: 995.09
#   Academic Std Deviation: 2.70
#   Wellbeing Std Deviation: 0.11
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 499:
#   Total Normalized Reward: 991.52
#   Academic Std Deviation: 4.81
#   Wellbeing Std Deviation: 0.58
#   Bullying Penalty: 0.0500
# ----------------------------------------

# %%
# Evaluation

# %%
# 1. Import Libraries
import torch
import numpy as np
import matplotlib.pyplot as plt

# 2. Load DQN Model and Agent Classes

# Define the DQN model (same as training)
import torch.nn as nn

class DQNModel(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQNModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Define the agent
class DQNAgent:
    def __init__(self, input_dim, output_dim):
        self.model = DQNModel(input_dim, output_dim)
        self.output_dim = output_dim
        self.epsilon = 0.0  # Evaluation: no exploration

    def choose_action(self, state):
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        q_values = self.model(state_tensor)
        return torch.argmax(q_values).item()

# 3. Load Trained Model
agent = DQNAgent(input_dim=4, output_dim=4)
agent.model.load_state_dict(torch.load('model_after_500_episodes.pth'))
agent.model.eval()

# 4. Define Evaluation Loop
n_eval_episodes = 20
academic_stds = []
wellbeing_stds = []
bullying_penalties = []
normalized_rewards = []

for episode in range(n_eval_episodes):
    state_data = env.reset()
    total_custom_reward = 0
    steps = 0
    done = False

    while not done:
        classroom_sizes = np.array(state_data['classroom_sizes']) / 10000
        action = agent.choose_action(classroom_sizes)
        next_state_data, _, done, academic_std, wellbeing_std, bullying_penalty = env.step(f"Class_{action}")
        next_classroom_sizes = np.array(next_state_data['classroom_sizes']) / 10000

        custom_reward = (
            0.7 * (1 - min(academic_std, 5) / 10) +
            0.2 * (1 - wellbeing_std / 10) +
            0.1 * (1 - bullying_penalty * 100)
        )

        total_custom_reward += custom_reward
        state_data = next_state_data
        steps += 1

    normalized_reward = (total_custom_reward / steps) * 1000
    normalized_rewards.append(normalized_reward)
    academic_stds.append(academic_std)
    wellbeing_stds.append(wellbeing_std)
    bullying_penalties.append(bullying_penalty)

    print(f"Episode {episode + 1}:")
    print(f"  Normalized Reward: {normalized_reward:.2f}")
    print(f"  Academic Std Deviation: {academic_std:.2f}")
    print(f"  Wellbeing Std Deviation: {wellbeing_std:.2f}")
    print(f"  Bullying Penalty: {bullying_penalty:.4f}")
    print("-" * 40)

# 5. Plot Results
episodes = np.arange(1, n_eval_episodes + 1)

plt.figure(figsize=(8, 5))
plt.plot(episodes, academic_stds, marker='o')
plt.title('Academic Std Deviation (Evaluation)')
plt.xlabel('Episode')
plt.ylabel('Academic Std Deviation')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, wellbeing_stds, marker='o', color='orange')
plt.title('Wellbeing Std Deviation (Evaluation)')
plt.xlabel('Episode')
plt.ylabel('Wellbeing Std Deviation')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, bullying_penalties, marker='o', color='green')
plt.title('Bullying Penalty (Evaluation)')
plt.xlabel('Episode')
plt.ylabel('Bullying Penalty')
plt.grid(True)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(episodes, normalized_rewards, marker='o', color='purple')
plt.title('Normalized Reward (Evaluation)')
plt.xlabel('Episode')
plt.ylabel('Normalized Reward')
plt.grid(True)
plt.show()

# Optionally print overall averages
print("Average over evaluation episodes:")
print(f"  Avg Reward: {np.mean(normalized_rewards):.2f}")
print(f"  Avg Academic Std: {np.mean(academic_stds):.2f}")
print(f"  Avg Wellbeing Std: {np.mean(wellbeing_stds):.2f}")
print(f"  Avg Bullying Penalty: {np.mean(bullying_penalties):.4f}")
# Out:
# Episode 1:
#   Normalized Reward: 999.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0100
# ----------------------------------------
# Episode 2:
#   Normalized Reward: 997.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 3:
#   Normalized Reward: 997.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 4:
#   Normalized Reward: 1000.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0000
# ----------------------------------------
# Episode 5:
#   Normalized Reward: 998.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0200
# ----------------------------------------
# Episode 6:
#   Normalized Reward: 996.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 7:
#   Normalized Reward: 999.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0100
# ----------------------------------------
# Episode 8:
#   Normalized Reward: 996.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 9:
#   Normalized Reward: 997.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 10:
#   Normalized Reward: 999.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0100
# ----------------------------------------
# Episode 11:
#   Normalized Reward: 1000.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0000
# ----------------------------------------
# Episode 12:
#   Normalized Reward: 997.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 13:
#   Normalized Reward: 999.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0100
# ----------------------------------------
# Episode 14:
#   Normalized Reward: 997.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 15:
#   Normalized Reward: 997.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 16:
#   Normalized Reward: 1000.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0000
# ----------------------------------------
# Episode 17:
#   Normalized Reward: 996.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 18:
#   Normalized Reward: 997.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0300
# ----------------------------------------
# Episode 19:
#   Normalized Reward: 996.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Episode 20:
#   Normalized Reward: 996.00
#   Academic Std Deviation: 0.00
#   Wellbeing Std Deviation: 0.00
#   Bullying Penalty: 0.0400
# ----------------------------------------
# Average over evaluation episodes:
#   Avg Reward: 997.65
#   Avg Academic Std: 0.00
#   Avg Wellbeing Std: 0.00
#   Avg Bullying Penalty: 0.0235

# %%
torch.save(agent.model.state_dict(), "final_trained_model.pth")

# %%
pip install ortools
# Out:
# Requirement already satisfied: ortools in /opt/anaconda3/lib/python3.11/site-packages (9.12.4544)
# Requirement already satisfied: absl-py>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ortools) (2.2.2)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.11/site-packages (from ortools) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ortools) (2.1.4)
# Requirement already satisfied: protobuf<5.30,>=5.29.3 in /opt/anaconda3/lib/python3.11/site-packages (from ortools) (5.29.4)
# Requirement already satisfied: immutabledict>=3.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ortools) (4.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->ortools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->ortools) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=2.0.0->ortools) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ortools.sat.python import cp_model
import pandas as pd
import numpy as np

# Step 1: Load the dataset
df = pd.read_csv("synthetic_student_data.csv")

# Extract relevant features
academic_scores = df["Academic_Performance"].to_numpy()
wellbeing_scores = df["pwi_wellbeing"].to_numpy()
bullying_scores = df["bullying"].to_numpy()

# Settings
num_students = len(df)
num_classes = 40
max_allowed_academic_diff = 15
max_allowed_wellbeing_diff = 2
max_bullies_per_class = 2
bully_threshold = 7

# Create bullying matrix
bullying_matrix = np.outer(bullying_scores, bullying_scores) * 0.1
np.fill_diagonal(bullying_matrix, 0)

# Identify high-bullying students
high_bully_indices = [i for i in range(num_students) if bullying_scores[i] >= bully_threshold]

# Initialize CP model
model = cp_model.CpModel()

# Decision Variables: student_class[i][j] = 1 if student i is assigned to class j
student_class = [
    [model.NewBoolVar(f'student_{i}_class_{j}') for j in range(num_classes)]
    for i in range(num_students)
]

# Constraint 1: Each student assigned to one class
for i in range(num_students):
    model.Add(sum(student_class[i]) == 1)

# Constraint 2: Class size balance
min_size = num_students // num_classes
max_size = min_size + 1  # for remainder distribution

for j in range(num_classes):
    class_size = sum(student_class[i][j] for i in range(num_students))
    model.Add(class_size >= min_size)
    model.Add(class_size <= max_size)

# Constraint 3: Academic and wellbeing balance (approximate)
class_academic = [model.NewIntVar(0, num_students * 100, f'acad_sum_{j}') for j in range(num_classes)]
class_wellbeing = [model.NewIntVar(0, num_students * 10, f'wellbeing_sum_{j}') for j in range(num_classes)]
class_sizes = [sum(student_class[i][j] for i in range(num_students)) for j in range(num_classes)]

for j in range(num_classes):
    model.Add(class_academic[j] == sum(int(academic_scores[i]) * student_class[i][j] for i in range(num_students)))
    model.Add(class_wellbeing[j] == sum(int(wellbeing_scores[i]) * student_class[i][j] for i in range(num_students)))

avg_acad = int(np.mean(academic_scores))
avg_well = int(np.mean(wellbeing_scores))

for j in range(num_classes):
    # Academic
    diff_acad = model.NewIntVar(-1000, 1000, f'diff_acad_{j}')
    model.Add(diff_acad == class_academic[j] - class_sizes[j] * avg_acad)
    model.AddAbsEquality(model.NewIntVar(0, max_allowed_academic_diff, ''), diff_acad)

    # Wellbeing
    diff_well = model.NewIntVar(-1000, 1000, f'diff_well_{j}')
    model.Add(diff_well == class_wellbeing[j] - class_sizes[j] * avg_well)
    model.AddAbsEquality(model.NewIntVar(0, max_allowed_wellbeing_diff, ''), diff_well)

# Constraint 4: Limit bullies per class
for j in range(num_classes):
    bullies_in_class = [student_class[i][j] for i in high_bully_indices]
    model.Add(sum(bullies_in_class) <= max_bullies_per_class)

# Objective: minimize bullying co-assignments
bullying_terms = []
for i in range(num_students):
    for j in range(i + 1, num_students):
        if bullying_matrix[i][j] > 0:
            for c in range(num_classes):
                both_same = model.NewBoolVar(f'both_{i}_{j}_class_{c}')
                model.AddBoolAnd([student_class[i][c], student_class[j][c]]).OnlyEnforceIf(both_same)
                model.AddBoolOr([student_class[i][c].Not(), student_class[j][c].Not()]).OnlyEnforceIf(both_same.Not())
                weight = int(bullying_matrix[i][j] * 1000)
                bullying_terms.append((both_same, weight))

model.Minimize(sum(term * weight for term, weight in bullying_terms))

# Solve
solver = cp_model.CpSolver()
status = solver.Solve(model)

# Output
if status in (cp_model.OPTIMAL, cp_model.FEASIBLE):
    assignments = [[] for _ in range(num_classes)]
    for i in range(num_students):
        for j in range(num_classes):
            if solver.Value(student_class[i][j]):
                assignments[j].append(i)
                break

    print("Class Assignments Summary:")
    for j, group in enumerate(assignments):
        print(f"Class {j+1} ({len(group)} students):")
        acad_vals = [academic_scores[i] for i in group]
        well_vals = [wellbeing_scores[i] for i in group]
        bully_vals = [bullying_scores[i] for i in group]
        print(f"  Avg Acad: {np.mean(acad_vals):.2f}, Std: {np.std(acad_vals):.2f}")
        print(f"  Avg Wellbeing: {np.mean(well_vals):.2f}, Std: {np.std(well_vals):.2f}")
        print(f"  Bullies ≥ {bully_threshold}: {sum(v >= bully_threshold for v in bully_vals)}")
else:
    print("No feasible solution found.")
